# %% [markdown]
# Chordify has a page with only artists. Let's turn this page into a list of artist urls that we can then feed the scraper.
#
# Then the scraper will go through the list of artist urls:
#
# At each url, it will first:
# 1. parse artist page and return song
# 2. parse song page and return chords (and bar length)
#
# Then, for each artist, we can yield a dictionary of song name and chords.

# %%
# Out:
#   Cell In[2], line 1
# ...
